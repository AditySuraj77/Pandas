# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name":["Samson", "Siraj", "Dhawan", "Iyer", "Ishan", "Shardul"],
    "Type":["Bats-man", "Bowler", "Bats-man", "Batsman", "Batsman", "All- Rounder"],
    "Age":[27, 28, 36,27, 24, 30]
    
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       Name          Type  Age
# 0   Samson      Bats-man   27
# 1    Siraj        Bowler   28
# 2   Dhawan      Bats-man   36
# 3     Iyer       Batsman   27
# 4    Ishan       Batsman   24
# 5  Shardul  All- Rounder   30

# %%
df.to_csv("player.csv")

# %%
df.head(2)
# Out:
#      Name      Type  Age
# 0  Samson  Bats-man   27
# 1   Siraj    Bowler   28

# %%
df.tail(2)
# Out:
#       Name          Type  Age
# 4    Ishan       Batsman   24
# 5  Shardul  All- Rounder   30

# %%
df.describe()
# Out:
#              Age
# count   6.000000
# mean   28.666667
# std     4.082483
# min    24.000000
# 25%    27.000000
# 50%    27.500000
# 75%    29.500000
# max    36.000000

# %%
ad = pd.read_csv("players.csv")

# %%
ad
# Out:
#    Unnamed: 0     Name          Type  Age    Bests
# 0           0   Samson      Bats-man   27  119runs
# 1           1    Siraj        Bowler   28   May-73
# 2           2   Dhawan      Bats-man   36      143
# 3           3     Iyer       Batsman   27      109
# 4           4    Ishan       Batsman   24       68
# 5           5  Shardul  All- Rounder   30   Jun-68

# %%
newdt = pd.Series(np.random.rand(100), index=np.arange(100))

# %%
newdt
# Out:
# 0     0.962382
# 1     0.733819
# 2     0.260258
# 3     0.115765
# 4     0.827574
#         ...
# 95    0.737608
# 96    0.288659
# 97    0.477639
# 98    0.314535
# 99    0.491689
# Length: 100, dtype: float64

# %%
type(newdt)
# Out:
# pandas.core.series.Series

# %%
newdt = pd.DataFrame(np.random.rand(100,5), index=np.arange(100))

# %%
newdt
# Out:
#            0         1         2         3         4
# 0   0.181700  0.930298  0.751053  0.982949  0.986950
# 1   0.166268  0.074089  0.318234  0.640288  0.578763
# 2   0.329812  0.692384  0.421444  0.753953  0.069224
# 3   0.106635  0.839836  0.101244  0.833626  0.893466
# 4   0.762367  0.076258  0.041377  0.695534  0.872316
# ..       ...       ...       ...       ...       ...
# 95  0.413919  0.390055  0.353375  0.136286  0.206570
# 96  0.701935  0.860046  0.246449  0.694846  0.669743
# 97  0.342076  0.639252  0.369994  0.759782  0.827450
# 98  0.341507  0.715422  0.838055  0.131738  0.369270
# 99  0.948908  0.480561  0.897543  0.300873  0.915875
#
# [100 rows x 5 columns]

# %%
type(newdt)
# Out:
# pandas.core.frame.DataFrame

# %%
newdt.describe()
# Out:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.454973    0.553051    0.504881    0.508251    0.560504
# std      0.282667    0.296290    0.302250    0.305429    0.297560
# min      0.014736    0.011655    0.003367    0.010778    0.004491
# 25%      0.206827    0.245913    0.241610    0.204781    0.335173
# 50%      0.413301    0.612616    0.476603    0.527125    0.578561
# 75%      0.701683    0.812478    0.788291    0.755410    0.830774
# max      0.984912    0.989790    0.991110    0.982949    0.986950

# %%
newdt.to_numpy()
# Out:
# array([[0.18169981, 0.93029798, 0.75105297, 0.98294885, 0.98694977],
#        [0.16626809, 0.07408944, 0.31823408, 0.64028824, 0.57876252],
#        [0.32981172, 0.69238358, 0.42144367, 0.75395321, 0.06922432],
#        [0.10663521, 0.83983615, 0.10124387, 0.83362598, 0.89346571],
#        [0.7623672 , 0.07625787, 0.04137704, 0.69553383, 0.87231596],
#        [0.91975026, 0.20408059, 0.77488987, 0.68482271, 0.92884598],
#        [0.77516023, 0.48787972, 0.95163966, 0.20552441, 0.11307621],
#        [0.70159922, 0.7586792 , 0.7875615 , 0.94810449, 0.40557107],
#        [0.79674236, 0.85880576, 0.60118999, 0.46754616, 0.97309786],
#        [0.17526319, 0.75014072, 0.9085073 , 0.29418105, 0.58421149],
#        [0.85549271, 0.91832388, 0.55043176, 0.01250741, 0.88064252],
#        [0.23822678, 0.78846447, 0.02670331, 0.83927316, 0.35330674],
#        [0.8030954 , 0.18507492, 0.77469418, 0.92389482, 0.12777944],
#        [0.11136478, 0.91637834, 0.18629311, 0.74945774, 0.97669872],
# ...

# %%
newdt.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.181700  0.166268  0.329812  0.106635  0.762367  0.919750  0.775160
# 1  0.930298  0.074089  0.692384  0.839836  0.076258  0.204081  0.487880
# 2  0.751053  0.318234  0.421444  0.101244  0.041377  0.774890  0.951640
# 3  0.982949  0.640288  0.753953  0.833626  0.695534  0.684823  0.205524
# 4  0.986950  0.578763  0.069224  0.893466  0.872316  0.928846  0.113076
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.701599  0.796742  0.175263  ...  0.318208  0.945769  0.584137  0.239734
# 1  0.758679  0.858806  0.750141  ...  0.172213  0.842996  0.303738  0.011655
# 2  0.787561  0.601190  0.908507  ...  0.158628  0.850068  0.003367  0.833023
# 3  0.948104  0.467546  0.294181  ...  0.862398  0.163718  0.728588  0.099465
# 4  0.405571  0.973098  0.584211  ...  0.454806  0.545689  0.805077  0.478806
#
#          94        95        96        97        98        99
# ...

# %%
newdt2 = newdt

# %%
newdt2[0][0] = 0.1045

# %%
newdt2
# Out:
#            0         1         2         3         4
# 0   0.104500  0.930298  0.751053  0.982949  0.986950
# 1   0.166268  0.074089  0.318234  0.640288  0.578763
# 2   0.329812  0.692384  0.421444  0.753953  0.069224
# 3   0.106635  0.839836  0.101244  0.833626  0.893466
# 4   0.762367  0.076258  0.041377  0.695534  0.872316
# ..       ...       ...       ...       ...       ...
# 95  0.413919  0.390055  0.353375  0.136286  0.206570
# 96  0.701935  0.860046  0.246449  0.694846  0.669743
# 97  0.342076  0.639252  0.369994  0.759782  0.827450
# 98  0.341507  0.715422  0.838055  0.131738  0.369270
# 99  0.948908  0.480561  0.897543  0.300873  0.915875
#
# [100 rows x 5 columns]

# %%
newdt.loc[0,0] = 1111

# %%
newdt.head(2)
# Out:
#              0         1         2         3         4
# 0  1111.000000  0.930298  0.751053  0.982949  0.986950
# 1     0.166268  0.074089  0.318234  0.640288  0.578763

# %%
newdt.columns = list("ABCDE")

# %%
newdt
# Out:
#               A         B         C         D         E
# 0   1111.000000  0.930298  0.751053  0.982949  0.986950
# 1      0.166268  0.074089  0.318234  0.640288  0.578763
# 2      0.329812  0.692384  0.421444  0.753953  0.069224
# 3      0.106635  0.839836  0.101244  0.833626  0.893466
# 4      0.762367  0.076258  0.041377  0.695534  0.872316
# ..          ...       ...       ...       ...       ...
# 95     0.413919  0.390055  0.353375  0.136286  0.206570
# 96     0.701935  0.860046  0.246449  0.694846  0.669743
# 97     0.342076  0.639252  0.369994  0.759782  0.827450
# 98     0.341507  0.715422  0.838055  0.131738  0.369270
# 99     0.948908  0.480561  0.897543  0.300873  0.915875
#
# [100 rows x 5 columns]

# %%
newdt.loc[0,0] = "Sampu"

# %%
newdt
# Out:
#               A         B         C         D         E      0
# 0   1111.000000  0.930298  0.751053  0.982949  0.986950  Sampu
# 1      0.166268  0.074089  0.318234  0.640288  0.578763    NaN
# 2      0.329812  0.692384  0.421444  0.753953  0.069224    NaN
# 3      0.106635  0.839836  0.101244  0.833626  0.893466    NaN
# 4      0.762367  0.076258  0.041377  0.695534  0.872316    NaN
# ..          ...       ...       ...       ...       ...    ...
# 95     0.413919  0.390055  0.353375  0.136286  0.206570    NaN
# 96     0.701935  0.860046  0.246449  0.694846  0.669743    NaN
# 97     0.342076  0.639252  0.369994  0.759782  0.827450    NaN
# 98     0.341507  0.715422  0.838055  0.131738  0.369270    NaN
# 99     0.948908  0.480561  0.897543  0.300873  0.915875    NaN
#
# [100 rows x 6 columns]

# %%
newdt.drop(0, axis=1)
# Out:
#               A         B         C         D         E
# 0   1111.000000  0.930298  0.751053  0.982949  0.986950
# 1      0.166268  0.074089  0.318234  0.640288  0.578763
# 2      0.329812  0.692384  0.421444  0.753953  0.069224
# 3      0.106635  0.839836  0.101244  0.833626  0.893466
# 4      0.762367  0.076258  0.041377  0.695534  0.872316
# ..          ...       ...       ...       ...       ...
# 95     0.413919  0.390055  0.353375  0.136286  0.206570
# 96     0.701935  0.860046  0.246449  0.694846  0.669743
# 97     0.342076  0.639252  0.369994  0.759782  0.827450
# 98     0.341507  0.715422  0.838055  0.131738  0.369270
# 99     0.948908  0.480561  0.897543  0.300873  0.915875
#
# [100 rows x 5 columns]

# %%
newdt.iloc[[0,1], [1,2]]
# Out:
#           B         C
# 0  0.930298  0.751053
# 1  0.074089  0.318234

# %%
newdt.drop(['A', 'D', 'E'], axis=1)
# Out:
#            B         C      0
# 0   0.930298  0.751053  Sampu
# 1   0.074089  0.318234    NaN
# 2   0.692384  0.421444    NaN
# 3   0.839836  0.101244    NaN
# 4   0.076258  0.041377    NaN
# ..       ...       ...    ...
# 95  0.390055  0.353375    NaN
# 96  0.860046  0.246449    NaN
# 97  0.639252  0.369994    NaN
# 98  0.715422  0.838055    NaN
# 99  0.480561  0.897543    NaN
#
# [100 rows x 3 columns]
